# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Differnt charts
# 1. Bar charts
# 2. Pie charts
# 3. Bar graph
# 4. Line graph
# 5. Scatter plot

# %% [markdown]
# # Steps involved in EDA
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Data Sourcing
# This is the step where we collect the data , we've public data which is openly available and private data which is company owned and for access we would need to connect to admin to get it .

# %% [markdown]
# ## 2. Data cleaning
#
# It is needed to improve the quality of data so that it can be fed to ML models , after removing incorrect and irrelevant data our model's accuracy can improve .
#
# 1. Data Loading and Initial Inspection
# 2. Handle Invalid Values
# 3. Handle Missing Values
# 4. Outlier Detection and Treatment
# 5. Encode Categorical Variables (if any)
# 6. Feature Scaling
# 7. Train/Test Split or Cross-Validation
# 8. Model Training
#
# Why treat outliers before scaling?
# 1. Scaling is sensitive to outliers
# Methods like StandardScaler (which uses mean and standard deviation) are strongly influenced by outliers.
#
# If you scale first, outliers can distort the mean and standard deviation, leading to incorrect scaling for all other values.
#
# 2. Outliers can dominate scaled features
# For example, if a column has values mostly in the 10–20 range but one value is 500, after scaling, most of the values become very small (e.g., −0.1 to 0.1), and the outlier becomes a large value (e.g., 5 or −5). This gives the outlier disproportionate influence on models like logistic regression or k-NN.

# %% [markdown]
# ### a0. Handle invalid values
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### a. Handle missing values
# ![image.png](attachment:image.png)
#
#  If there is a column which is not related to other columns and has 50% missing values , we can delete it instead of impute
#  If some of the rows are missing ( 2-3% ) in this case we can impute or delete.
#
# #### All about data imputing
#
# ##### a.1 Techniques for data imputing
#
# ###### a.1.1 Using mean/median/mode/forwardfill / backwardfill for imputing
# Mode :- Categorical data
# When building model there's no right way , you can impute mean build model , then mpute median and test etc
#
# ##### a.1.1.1 Python code to handle missing values
#
# - `df.info()`
#   ➤ Gives quick information about the dataset.
#
# - `df.isnull().sum()`
#   ➤ Count of null values per column.
#
# - `df.dropna(axis=1)`
#   ➤ Drops columns that have null values. Use this when there are too many missing values in a column.
#
# - `df.dropna(axis=0)`
#   ➤ Drops rows that have null values. Use this when you want to keep the column but remove incomplete rows.
#
# - `df['property'] = df['property'].fillna(df['property'].mean())`
#   ➤ Fills NaN values with the mean of the column and modifies the original column.
#
# - `df['property'] = df['property'].bfill()`
#   ➤ Backward fills null values using the next valid value in the column.
#
# - `df['property'] = df['property'].ffill()`
#   ➤ Forward fills null values using the preceeding valid value in the column.
#
# ###### a.1.2 Algorithm Imputation
# Some machine learning models support handling missing values in datasets like KNN , Naive Bayes , Random Forest etc
#
# ###### a.1.3 Predicting the missing values
# Train a model using dataset with no missing value and that model will predict missing values for rows with missing values

# %% [markdown]
# ### b Outlier treatment
#
# ![image.png](attachment:image.png)
#
# 1. Donot get rid of outliers in time-series problem as each data point is important in such case and there might be patterns that model can find but not you .
# 2. If age is feature and some of them are outlier ( you can remove r keep them test by using both data in model)
#
# #### b.1 Python vis of outliers
#
# df['property].skew() -> Skewness in the data ideally should be 0
#
# df['property] = np.log(df['property])

# %% [markdown]
# ## b1 Feature encoding
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### b1. Python code
#
# LabelEncoder -> should be used for target column
#
#
# OneHotEncoder -> ( pd.get_dummies(df['property'])) -> one Hot
#
# Dummy Encoder -> ( pd.get_dummies(df['property'] , drop_first=True)) -> Reduces redundancy

# %% [markdown]
# ### c Standardization of data ( feature scaling)
# Rescale the values present in the features , standardize into one scale.
#
# #### c1. Divide my maximum ( Not good )
# #### c2. Standarization -> Scales so that mean is 0 and standard deviation is 1 ( data is normally distributed)
# Converting data based on mean and standard devation . Mean will be 0 and values will be between -3 and +3
# #### c3. Min-Max Normalization -> scale to 0 to 1 ( Data is not normally distributed)
# Between 0 and 1
# #### c4. Python code
# sklean import standardScalar and MinMaxScalar , use fit_transform on df , it'll do it on all the numerical columns .

# %% [markdown]
# ## 3. Data analysis
#
# ### 3.1 Categorical data analysis
#
# ####3.2 Univariante Analysis
#
# -> Can help determine if a feature is useful like if there is a column gender and male/female ratio is 1:1 , that would mean (insight) feature gender is not much of importance alone but maybe with multiple column it does.
#
# -> If age of a group is more than the parent group that would mean key importance
#
# -> Numberical or categorical , mostly for categorical data as it gives more insights for numerical we get spread or distribution of the data is .
#
# ####3.3 Bivariant analysis
#
# Data which has two variables and we want to determine the relationship between two features.
#
# Can we done for both numerical and categorical data .
#
# If when increase in one feature changes another positive coorelation , when reduces negative when near to 0 no relation.
#
#
# ####3.4 Multivariant analysis
#
# More than two variables
#
#
# ###3.2 Numerical Analysis
#
# Box plot
#
# Scatter plotts ( combination )
#
# ###3.3 Python code
#
# Univariant :-
#
# Seaborn.CountPlot() -> Total count per group
#
#
# Bi-variant :-
#
# categorical
#
# Seaborn.HistPlot() ->
#
#
#
# numerical
# Correlation -> range +1 to -1
#
# df.corr() -> Gives a tabular representation of correlation of all variables
#
# df.corr()['Property'].sort_values(ascending=False).plot(kind='bar') -> correlation wrt to "property"
#
# sns.heatmap(df.corr(), cmap='Paired')
#
# LineChart
#
# ConvertToBins
#
# KdePlot() -> Distribution showing like normal distribution
#
# ### Derived metric
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Feature binning , we create bins of the featuresand try to look at bins and understand distributions .
#
# #### Python code
#
# df['property'] = pd.cut(df.Age, [0,21,41,61,100] , labels, include_lowest=True)

# %% [markdown]
# ### Case Study
#
# Load and preview data
#
# Understand structure (df.info(), df.shape, df.dtypes)
#
# Check missing values (df.isnull().sum())
#
# Handle missing values
#
# Univariate and bivariate analysis (value_counts, boxplot, pairplot)
#
# Outlier detection
#
# Correlation analysis
#
# Feature importance (optional)
#
# Summary of insights

# %% [markdown]
# Data Cleaning
#
# 1. Handle N/A and Invalid data
# 2. Handle Outliers
#
# Data Analysis
#
# 3. Categorical Analysis - Univariant , Bi-variant , Multi-variant
# 4. Numerical analysis - Summary stats (Single) , Correlation
#
#
# Univariant :-
#
# 1. Check distribution
#
#
# Bi-vairant :-
#
# 1. Gender + Location original vs chrun let's say
#
# Multi-variant :-
#
# Combine multiple
#
#
# Numerical
#
# Correlaiton matrix , Bins
