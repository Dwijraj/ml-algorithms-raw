# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Differnt charts
# 1. Bar charts
# 2. Pie charts
# 3. Bar graph
# 4. Line graph
# 5. Scatter plot

# %% [markdown]
# # Steps involved in EDA
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Data Sourcing
# This is the step where we collect the data , we've public data which is openly available and private data which is company owned and for access we would need to connect to admin to get it .

# %% [markdown]
# ## 2. Data cleaning
#
# It is needed to improve the quality of data so that it can be fed to ML models , after removing incorrect and irrelevant data our model's accuracy can improve .
#
# a. Handle Missing values
# b. Standardization of data ( feature scaling)
# c. Outlier treatment
# ### d. Handle invalid values

# %% [markdown]
# ### a. Handle missing values
# ![image.png](attachment:image.png)
#
#  If there is a column which is not related to other columns and has 50% missing values , we can delete it instead of impute
#  If some of the rows are missing ( 2-3% ) in this case we can impute or delete.
#
# #### All about data imputing
#
# ##### a.1 Techniques for data imputing
#
# ###### a.1.1 Using mean/median/mode/forwardfill / backwardfill for imputing
# Mode :- Categorical data
# When building model there's no right way , you can impute mean build model , then mpute median and test etc
#
# ##### a.1.1.1 Python code to handle missing values
#
# - `df.info()`
#   ➤ Gives quick information about the dataset.
#
# - `df.isnull().sum()`
#   ➤ Count of null values per column.
#
# - `df.dropna(axis=1)`
#   ➤ Drops columns that have null values. Use this when there are too many missing values in a column.
#
# - `df.dropna(axis=0)`
#   ➤ Drops rows that have null values. Use this when you want to keep the column but remove incomplete rows.
#
# - `df['property'] = df['property'].fillna(df['property'].mean())`
#   ➤ Fills NaN values with the mean of the column and modifies the original column.
#
# - `df['property'] = df['property'].bfill()`
#   ➤ Backward fills null values using the next valid value in the column.
#
# - `df['property'] = df['property'].ffill()`
#   ➤ Forward fills null values using the preceeding valid value in the column.
#
# ###### a.1.2 Algorithm Imputation
# Some machine learning models support handling missing values in datasets like KNN , Naive Bayes , Random Forest etc
#
# ###### a.1.3 Predicting the missing values
# Train a model using dataset with no missing value and that model will predict missing values for rows with missing values

# %% [markdown]
# ### b Standardization of data ( feature scaling)
# Rescale the values present in the features , standardize into one scale.
#
# #### b1. Divide my maximum ( Not good )
# #### b2. Standarization -> Scales so that mean is 0 and standard deviation is 1 ( data is normally distributed)
# Converting data based on mean and standard devation . Mean will be 0 and values will be between -3 and +3
# #### b3. Min-Max Normalization -> scale to 0 to 1 ( Data is not normally distributed)
# Between 0 and 1
# #### b4. Python code
# sklean import standardScalar and MinMaxScalar , use fit_transform on df , it'll do it on all the numerical columns .

# %% [markdown]
# ### c Outlier treatment
#
# ![image.png](attachment:image.png)
